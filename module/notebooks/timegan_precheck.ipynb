# %%
import pandas as pd

# Load your LOB dataset
df = pd.read_parquet("data/raw/lob_synthetic.parquet")

print("Shape:", df.shape)
print("Columns:", df.columns.tolist())

# Show first few rows to inspect structure
df.head(5)
